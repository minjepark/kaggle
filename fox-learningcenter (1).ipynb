# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the FOX_Learning_Center/python Docker 
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
#Computer Science 
#데이터 불러오기
train = pd.read_csv('/kaggle/input/fox-learning/FOX_LC_train.csv')
test = pd.read_csv('/kaggle/input/fox-learning/FOX_LC_test.csv')

# %%
#Warming up to Learn(WL)
#컴퓨터 과학 
#인터넷 세상, Drag and Drop, 폴더 만들기, 더블클릭

from Warming_up_to_Learn.컴퓨터와_친해지기  
import 권누리

# %%
#Ready to Learn(RL)
#절차적 사고 #이진법 #디버그 #CS기초
from Ready_to_Learn.컴퓨터의_비밀 
import 박민제

# %%
#Ready to Learn(RL)
#프로그래밍 개념
#프로그램이란 무엇일까요? #일상 속 프로그래밍
from Ready_to_Learn.프로그래밍_개념
import 박수연

# %%
#Ready to Learn(RL)
#블록코딩, 스크래치
from Ready_to_Learn.Scratch 
import 김형준

# %%
#Ready to Learn(RL)
#절차적 사고 #Scratch #CS기초
from Ready_to_Learn.디자인_씽킹
import 김영진

# %%
#Play Learn(PL)
#CS 
#활용단계 

from Play_Learn.프로그래밍_2_Scratch 
import

# %%
#Play Learn(PL)
#활용단계 

from Play_Learn.프로그래밍_3_APP_Inventor
import

# %%
#Play Learn(PL)
#코딩이 술술~
#활용단계 
#파이썬, 텍스트 코딩
from Play_Learn.프로그래밍_4_Python
import

# %%
#Creative Learn(CL)
#세상 모든 문제는 내가 해결할 수 있어!
#파이썬, 어플개발, Django, 실생활 문제 해결, web publishing
from Creative_Learn.코드로 앱 만들기
import
